# %% [markdown]
# ### Data Preparation

# %%
# import depenedencies 
# read data from csv file
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

crypto_df = pd.read_csv('crypto_data.csv')
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
crypto_df = crypto_df.drop('Unnamed: 0', axis=1)
# filter for cryptocurrencies that are currently trading 
trading_crypto = crypto_df[crypto_df['IsTrading'] != False]
# trading_crypto

# drop 'IsTrading' column; all currencies in this dataframe are currently trading
trading_crypto = trading_crypto.drop('IsTrading', axis=1)
trading_crypto
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 1         365Coin          X11   PoW/PoS              NaN      2300000000
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 3       SixEleven      SHA-256       PoW              NaN          611000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# 1243   Super Zero       Ethash       PoW              NaN      1000000000
# 1244          UOS      SHA-256      DPoI              NaN      1000000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# drop any rows with missing values
trading_crypto.dropna(inplace=True)
trading_crypto
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 4             808      SHA-256   PoW/PoS     0.000000e+00               0
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# filter for cryptocurrencies that have been mined
mined_crypto = trading_crypto.loc[trading_crypto['TotalCoinsMined'] > 0]
# mined_crypto = mined_crypto.drop('TotalCoinsMined', axis=1)
mined_crypto
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 2         404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# 7         Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# 8        Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# 1238       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# 1242      Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245       Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# 1246      Horizen     Equihash       PoW     7.296538e+06        21000000
# 1247  BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# drop coin name column
mined_crypto.drop(columns=['CoinName'], inplace=True)
mined_crypto
# Out:
# C:\Users\hmwhi\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# ...

# %%
mined_crypto.shape
# Out:
# (532, 4)

# %%
# convert 'Algorithm' & 'ProofType' columns to numeric values
#  get dummy variables for 'Algorithm' & 'ProofType' columns
dummies_df = pd.get_dummies(mined_crypto, prefix=['Algorithm', 'ProofType'], columns=['Algorithm', 'ProofType'])
dummies_df
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01              42                                 0
# 2        1.055185e+09       532000000                                 0
# 5        2.927942e+10    314159265359                                 0
# 7        1.792718e+07        21000000                                 0
# 8        1.076842e+08               0                                 0
# ...               ...             ...                               ...
# 1238     2.000000e+09      2000000000                                 0
# 1242     1.493105e+07       250000000                                 0
# 1245     9.802226e+08      1400222610                                 0
# 1246     7.296538e+06        21000000                                 0
# 1247     1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %% [markdown]
# The number of columns increased by 94

# %%
# scale the dataframe
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(dummies_df)

# %% [markdown]
# ### Dimensionality Reduction

# %%
# use pca to reduce the number of features
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9)
crypto_pca = pca.fit_transform(scaled_data)
crypto_pca.shape
# Out:
# (532, 74)

# %% [markdown]
# Performing dimensionality reduction with PCA decreased the number of features by 20

# %%
# use t-SNE to further reduce the number of features and visualize the results
from sklearn.manifold import TSNE

tsne = TSNE(learning_rate=100)
tsne_features = tsne.fit_transform(crypto_pca)
tsne_features.shape
# Out:
# C:\Users\hmwhi\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (532, 2)

# %% [markdown]
# t-SNE further reduced the number of features by 72

# %%
x = tsne_features[:, 0]
y = tsne_features[:, 1]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# The resulting cluster is very interesting. There is one large cluster, one small cluster, a significant outlier, as well as two "J-shaped" clusters within the main cluster.

# %%
# find the best number of clusters using k-means clustering
from sklearn.cluster import KMeans

inertia = []
k =list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i,random_state=42)
    km.fit(tsne_features)
    inertia.append(km.inertia_)
# Out:
# C:\Users\hmwhi\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1039: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# create elbow curve
data = {'k':k, 'inertia': inertia}
elbow_df = pd.DataFrame(data)
elbow_df
# Out:
#     k        inertia
# 0   1  203356.437500
# 1   2  121738.523438
# 2   3   64290.386719
# 3   4   40607.269531
# 4   5   28257.164062
# 5   6   23857.011719
# 6   7   19826.337891
# 7   8   17537.804688
# 8   9   14775.205078
# 9  10   12120.345703

# %%
# plot the elbow curve
k_X = elbow_df['k']
k_Y= elbow_df['inertia']

plt.plot(k_X, k_Y)
plt.xticks(k)
plt.xlabel('# of clusters')
plt.ylabel('inertia')
plt.show()

# %% [markdown]
# #### Based on the chart of the elbow curve, the optimal number of clusters is 2
#
#
# ### Recommendation:
# Through machine learning analysis the cryptocurrencies can be grouped into 2 classifications. These classifications would be useful in the formation of an investment portfolio containing similar cryptocurrencies that are currently available for trading.
